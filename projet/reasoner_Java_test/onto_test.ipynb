# %%
import pandas as pd
# import json
df = pd.read_json("../../Zone_2000.json")

# %%
from owlready2 import *
import os
onto = get_ontology("http://test.org/onto_herelles.owl")

### Image Module
class Image(Thing):
    namespace=onto
class Elements(Thing):
    namespace=onto
class Pixel(Elements):
    pass
class Object_Geo(Elements):
    pass

### Evolution Module
class Evolution_Process(Thing):
    namespace=onto
class Pixel_Evolution_Process(Evolution_Process):
    pass
class ObjGeo_Evolution_Process(Evolution_Process):
    pass

### Temporal Module
class Valid_Time(Thing):
    namespace=onto
class Valid_Instant(Valid_Time):
    pass
class Valid_Interval(Valid_Time):
    pass

### Herelles Module
class State_Geo(Thing):
    namespace=onto

class Surface_artificialisee(State_Geo):
    pass
class Vegetation_urbaine(Surface_artificialisee):
    pass
class Arbre_urbain(Vegetation_urbaine):
    pass
class Pelouse(Vegetation_urbaine):
    pass
class Jardin(Vegetation_urbaine):
    pass
class Parc(Vegetation_urbaine):
    pass
class Alignement_darbres_urbain(Vegetation_urbaine):
    pass
class Ensemble_darbres_urbain(Vegetation_urbaine):
    pass
class Bati(Surface_artificialisee):
    pass
class Bati_residentiel(Bati):
    pass
class TU_discontinu(Bati_residentiel):
    pass
class TU_discontinu_collectif(TU_discontinu):
    pass
class TU_discontinu_individuel(TU_discontinu):
    pass
class TU_continu(Bati_residentiel):
    pass
class TU_continu_collectif(TU_continu):
    pass
class TU_continu_individuel(TU_continu):
    pass
class Bati_activite(Bati):
    pass
class Zone_industrielle_commerciale_ou_tertiaire(Bati_activite):
    pass
class Bâtiment_rural(Bati_activite):
    pass
class Serre(Bati_activite):
    pass
class Autre_Bati(Bati):
    pass
class Infrastructure_de_transport(Surface_artificialisee):
    pass
class Voies_de_communication(Infrastructure_de_transport):
    pass
class Route(Voies_de_communication):
    pass
class Chemin(Voies_de_communication):
    pass
class Chemin_de_fer(Voies_de_communication):
    pass
class Route_Grande_Vitesse(Voies_de_communication):
    pass
class Autre_Route(Voies_de_communication):
    pass
class Equipement_transports(Infrastructure_de_transport):
    pass
class Parking(Equipement_transports):
    pass
class Zone_aeroportuaire(Equipement_transports):
    pass
class Ilot_de_circulation(Equipement_transports):
    pass
class Carrefour(Equipement_transports):
    pass
class Pont(Equipement_transports):
    pass
class Echangeur(Equipement_transports):
    pass
class Autre_artificialisation(Surface_artificialisee):
    pass
class Cimetiere(Autre_artificialisation):
    pass
class Place(Autre_artificialisation):
    pass
class Terrain_vacant(Autre_artificialisation):
    pass
class Terrain_de_Sport(Autre_artificialisation):
    pass
class Piscine_exterieure(Autre_artificialisation):
    pass
class Zone_sportif_loisir(Autre_artificialisation):
    pass
class Zone_dextraction(Autre_artificialisation):
    pass

class Eau(State_Geo):
    pass
class Surface_en_eau_artificielle(Eau):
    pass
class Canal(Surface_en_eau_artificielle):
    pass
class Bassin_artificiel(Surface_en_eau_artificielle):
    pass
class Surface_en_eau_naturelle(Eau):
    pass
class Etendue_deau(Surface_en_eau_naturelle):
    pass
class Cours_deau(Surface_en_eau_naturelle):
    pass

class Espaces_agricoles(State_Geo):
    pass
class Parcelle_agricole(Espaces_agricoles):
    pass
class Vigne(Parcelle_agricole):
    pass
class Autres_cultures(Parcelle_agricole):
    pass
class Surface_herbeuse_agricole(Parcelle_agricole):
    pass
class Element_boise_agricole(Espaces_agricoles):
    pass
class Groupe_darbres_agricole_sylviculture(Element_boise_agricole):
    pass
class Alignement_darbres_agricole(Element_boise_agricole):
    pass
class Verger(Element_boise_agricole):
    pass
class Autre_vegetation_agricole(Espaces_agricoles):
    pass
class Haie(Autre_vegetation_agricole):
    pass

class Espaces_forestiers_et_naturels(State_Geo):
    pass
class Foret(Espaces_forestiers_et_naturels):
    pass
class Espace_libre_naturel(Espaces_forestiers_et_naturels):
    pass
class Sable(Espace_libre_naturel):
    pass
class Zones_humides(Espaces_forestiers_et_naturels):
    pass
class Vegetation_autre(Espaces_forestiers_et_naturels):
    pass
class Surface_herbeuse_naturelle(Vegetation_autre):
    pass

### Object properties
class composed_by(ObjectProperty, InverseFunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Image]
    range     = [Elements]
class has_pixels(ObjectProperty, InverseFunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Object_Geo]
    range     = [Pixel]
class has_state(ObjectProperty, FunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Elements]
    range     = [State_Geo]
class is_involved(ObjectProperty):
    namespace=onto
    domain    = [Elements]
    range     = [Evolution_Process]
class has_duration(ObjectProperty):
    namespace=onto
    domain    = [Evolution_Process]
    range     = [Valid_Time]
class has_time(ObjectProperty, FunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [State_Geo]
    range     = [Valid_Time]

### ajout de la classe Zone :
class Zone(Elements):
    namespace=onto

class ZoneEau(Zone):
    pass

class ZoneEA(Zone):
    pass

class ZoneArticle1(Zone):
    pass

class Zone_Z2(Zone):
    pass

class ZoneSA(Zone):
    pass

# ajout de relation pour cette derniere :
class has_rules(ObjectProperty, InverseFunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Image]
    range     = [Zone]

class z_has_pixels (ObjectProperty, InverseFunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Zone]
    range     = [Pixel]

class Candidate_Final_State(ObjectProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Elements]
    range     = [State_Geo]

class is_in(ObjectProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Object_Geo]
    range     = [Zone]

class contains_object(ObjectProperty,  IrreflexiveProperty):
    namespace=onto
    domain    = [Zone]
    range     = [Object_Geo]
    inverse_property = is_in

class is_pixel_of_zone(ObjectProperty, FunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Pixel]
    range     = [Zone]
    inverse_property = z_has_pixels

class is_pixel_of(ObjectProperty, FunctionalProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Pixel]
    range     = [Object_Geo]
    inverse_property = has_pixels

### Obstacle :
class Obstacle(Thing):
    namespace = onto

class Ecoulement_des_crues(Obstacle):
    pass

class Remblais(Obstacle):
    pass

class createSome(ObjectProperty, IrreflexiveProperty):
    namespace=onto
    domain    = [Object_Geo]
    range     = [Obstacle]

'''
### Exemple_1: 2 Objets appartiennent a 1 seul Zone
'''
# ### Valid_time :
# t1 = Valid_Time("t1")
# remblais1 = Remblais("rembais1")
# crues1 = Ecoulement_des_crues("crues1")

# ### State_geo : (Jardin et Vigne)
# jardin = Jardin("jardin_1", has_time = t1)
# eau = Eau("eau_1", has_time = t1)
# Bati_indu = Zone_industrielle_commerciale_ou_tertiaire("bati_industrielle", has_time = t1)
# EA = Espaces_agricoles("EA_1", has_time = t1)

# ### Object_geo with his pixel :
# px1 = Pixel("Px_1", has_state = Bati_indu)
# px2 = Pixel("Px_2", has_state = EA)
# px3 = Pixel("Px_3", has_state = Bati_indu)

# #L'un OU l'autre :
# #obj1 = Object_Geo("obj_1", has_pixels = [px1], has_state = eau, createSome = [remblais1])
# #obj2 = Object_Geo("obj_2", has_pixels = [px2], has_state = EA, createSome = [crues1])
# obj1 = Object_Geo("obj_1", has_pixels = [px1], has_state = Bati_indu, Candidate_Final_State = [Bati_indu])
# obj2 = Object_Geo("obj_2", has_pixels = [px2], has_state = EA, Candidate_Final_State = [Bati_indu])
# obj3 = Object_Geo("obj_3", has_pixels = [px3], has_state = Bati_indu, Candidate_Final_State = [EA])

# ### Zone :
# z1 = ZoneArticle1("zone_1", z_has_pixels = [px1,px3])
# z2 = Zone("zone_2", z_has_pixels = [px2], Candidate_Final_State = [EA])

# ### Image creation :
# img_1 = Image("Img", composed_by = [obj1, obj2, obj3])
# img_2 = Image("Img2", has_rules= [z1,z2])


'''
### Exemple_2: 1 Objet appartient a 2 Zones différentes
# Dans l'exemple ci dessous : 
# - si on change la Candidate_Final_State de l'objet en "Bati_indu" -> inconsistance (car z1 = zonearticle)
# - si on change la Candidate_Final_State de l'objet en "eau" -> inconsistance (car (z2 = Zone Candidate_Final_State a Espace_Agricole))
'''
t1 = Valid_Time("t1")
Bati_indu = Zone_industrielle_commerciale_ou_tertiaire("bati_industrielle", has_time = t1)
bati_act = Bati_activite("bati_act", has_time = t1)
EA = Espaces_agricoles("EA_1", has_time = t1)

# Pixel
px1 = Pixel("Px_1", has_state = Bati_indu)
px2 = Pixel("Px_2", has_state = Bati_indu)

# Object
obj1 = Object_Geo("obj_1", has_pixels = [px1,px2], has_state = bati_act, Candidate_Final_State = [Bati_indu])

### Zone
z1 = ZoneArticle1("zone_1", z_has_pixels = [px1], contains_object = [obj1])
z2 = ZoneEA("zone_2", z_has_pixels = [px2], Candidate_Final_State = [EA], contains_object = [obj1])
# z1 = ZoneArticle1("zone_1", z_has_pixels = [px1])
# z2 = ZoneEA("zone_2", z_has_pixels = [px2], Candidate_Final_State = [EA])

### Image creation :
img_1 = Image("Img", composed_by = [obj1])
img_2 = Image("Img2", has_rules= [z1,z2])

'''
### Exemple_3: 2 objects, chacun dans 2 zones : 

# Dans l'exemple ci-dessous : si on change la Candidate_Final_State de n'importe lequel des 2 objects, alors nous avons une inconsistance :
# - si on change Candidate_Final_State en bati_indu -> inconsistance 
# - si on change Candidate_Final_State en "eau" -> inconsistance
# - D'ailleurs EA fonctionne car 1 Zone interdit les bati_indu mais pas les EA, et l'autre Oblige d'avor des EA.
'''
# t1 = Valid_Time("t1")
# jardin = Jardin("jardin_1", has_time = t1)
# eau = Eau("eau_1", has_time = t1)
# Bati_indu = Zone_industrielle_commerciale_ou_tertiaire("bati_industrielle", has_time = t1)
# EA = Espaces_agricoles("EA_1", has_time = t1)
# SA_1 = Surface_artificialisee("SA_1", has_time = t1)

# # Pixel :
# px1 = Pixel("Px_1", has_state = Bati_indu)
# px2 = Pixel("Px_2", has_state = Bati_indu)
# px3 = Pixel("Px_3", has_state = EA)
# px4 = Pixel("Px_4", has_state = EA)

# # Object :
# obj1 = Object_Geo("obj_1", has_pixels = [px1,px2], has_state = Bati_indu, Candidate_Final_State = [Bati_indu])
# obj2 = Object_Geo("obj_2", has_pixels = [px3,px4], has_state = Bati_indu, Candidate_Final_State = [Bati_indu])


# ### Zone :
# z1 = ZoneArticle1("zone_1", z_has_pixels = [px1,px3], contains_object = [obj1,obj2])
# z2 = ZoneSA("zone_2", z_has_pixels = [px2,px4], Candidate_Final_State = [SA_1], contains_object = [obj1,obj2])

# ### Image creation :
# img_1 = Image("Img", composed_by = [obj1, obj2])
# img_2 = Image("Img2", has_rules= [z1,z2])


try:
    os.mkdir('./src/main/resources')
except:
    print("tout est bon")

#sync_reasoner()
sync_reasoner_pellet(infer_property_values=True, infer_data_property_values=True)
print(list(default_world.inconsistent_classes()))
onto.save(file = "./src/main/resources/onto_herelles.owl", format = "rdfxml")
# Out:
# tout est bon
# * Owlready2 * Running Pellet...
#     java -Xmx2000M -cp /home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jena-iri-0.9.5.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/antlr-3.2.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/antlr-runtime-3.2.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/httpcore-4.2.2.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/httpclient-4.2.3.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/log4j-core-2.19.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jena-arq-2.10.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jgrapht-jdk1.5.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/log4j-api-2.19.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/xercesImpl-2.10.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jcl-over-slf4j-1.6.4.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/aterm-java-1.6.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/owlapi-distribution-3.4.3-bin.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jena-tdb-0.10.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/pellet-2.3.1.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/xml-apis-1.4.01.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/commons-codec-1.6.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/slf4j-log4j12-1.6.4.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/slf4j-api-1.6.4.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/log4j-1.2-api-2.19.0.jar:/home/maxime/.local/lib/python3.10/site-packages/owlready2/pellet/jena-core-2.10.0.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --infer-data-prop-values --ignore-imports /tmp/tmp3zrb0kgc
# []
# * Owlready2 * Pellet took 0.4278709888458252 seconds
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
onto = get_ontology("./src/main/resources/onto_herelles.owl").load()
with onto :    
    '''PAREIL !!!!'''
    #je créé une regle qui oblige un object_geo d'avoir un seul State_geo:    
    # Pixel.equivalent_to.append(Pixel & 
    #                            is_pixel_of.exactly(1,Object_Geo) & 
    #                            is_pixel_of_zone.exactly(1,Zone) & 
    #                            has_state.exactly(1,State_Geo) )

    # Zone.equivalent_to.append(Zone & 
    #                           Candidate_Final_State.some(State_Geo) )
    '''PAREIL !!!!'''

    ZoneArticle1.equivalent_to.append(Zone & 
                                      Not(contains_object.some(Candidate_Final_State.some(Zone_industrielle_commerciale_ou_tertiaire))) )
    
    ZoneEA.equivalent_to.append(Zone & contains_object.only(Candidate_Final_State.only(Espaces_agricoles)))
    # ZoneEA.equivalent_to.append(Zone & Candidate_Final_State.some(Espaces_agricoles))

    ZoneSA.equivalent_to.append(Zone & contains_object.only(Candidate_Final_State.only(Surface_artificialisee)))

    Zone_Z2.equivalent_to.append(Zone & contains_object.only(Candidate_Final_State.some(Parc) | Candidate_Final_State.some(Jardin)))
    Zone_Z2.equivalent_to.append(Zone & Candidate_Final_State.only(Jardin | Parc))
    
    ZoneEau.equivalent_to.append(Zone & contains_object.only(Candidate_Final_State.some(Eau)))
    '''PAREIL !!!!'''
    # ZoneEau.equivalent_to.append(Zone & Candidate_Final_State.some(Eau))

    # State_Geo.equivalent_to.append(State_Geo & (has_time.only(Valid_Time) & has_time.min(1,Valid_Time) & has_time.max(1,Valid_Time)))
    '''PAREIL !!!!'''
    #Et maintenant je fais en sorte que les sous-concepts de State_Geo soient disjoint les uns des autres :
    AllDifferent([Eau, Espaces_agricoles, Espaces_forestiers_et_naturels, Surface_artificialisee])  
    AllDifferent({Elements, Evolution_Process, Image, State_Geo, Valid_Time})
    AllDifferent({Object_Geo, Pixel, Zone})
    #AllDifferent({ZoneEA, ZoneArtificialisee, ZoneEau})

    #je créé une regle SWRL permettant de connaitre l'appartenance d'un objet a une zone:
    '''ICI JE CHANGE MOMENTANEMENT CA !!!!!'''
    # swrl_rule = """
    # Image(?i), Image(?i2),
    # composed_by(?i, ?o), has_rules(?i2,?z),
    # has_pixels(?o, ?p) , z_has_pixels(?z, ?p) -> contains_object(?z, ?o)"""

    # rule = Imp("DetectionObjectIsInZone")
    # rule.set_as_rule(swrl_rule)

    '''POTENTIELEMENT A REMETTRE PLUS TARD !!!!'''

    #sync_reasoner(infer_property_values = True, debug=2)
    
    onto.save(file = "./src/main/resources/onto_herelles.owl", format = "rdfxml")
    onto.save(file = "./onto_herelles.owl", format = "rdfxml")

# %%
onto = get_ontology("./src/main/resources/onto_herelles.owl").load()
Zone = onto.Zone

list_subclassesZone = []
for sc in list(Zone.subclasses()):
    if not(sc in list_subclassesZone):
        list_subclassesZone.append(sc)

list_obj = []
list_zone = []

for object in onto.individuals():
    if(type(object) is Object_Geo):
        list_obj.append(object)
    else:
        for sc in list_subclassesZone:
            if(str(type(object)) == str(sc)):
                list_zone.append(object)

for i in list_obj:
    print(i)

for i in list_zone:
    print(i)
# Out:
# onto_herelles.obj_1
# onto_herelles.zone_1
# onto_herelles.zone_2

# %% [markdown]
# ##### Exécution du code java pour récuperer les explications en cas d'ontologie inconsistante :

# %%
import subprocess
import os

def test_consistency():
    mvn_command = ['mvn', 'install']
    java_command = ['java', '-jar', 'target/my-project-1.0-SNAPSHOT-jar-with-dependencies.jar']

    try:
        subprocess.check_call(mvn_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    except subprocess.CalledProcessError as e:
        print(e)
        exit(1)

    try:
        output = subprocess.check_output(java_command, stderr=subprocess.STDOUT).decode()
        print("Result :", output)
    except subprocess.CalledProcessError as e:
        print(e)
        exit(1)

    if("COHERENTE" in output):
        return True, output
    else:
        return False, output

# %% [markdown]
# ### A faire seulement si l'ontologie est inconsistante :

# %% [markdown]
# ##### Clean la sortie du code java :

# %%
def clean_output_cons(txt):
    clean_output = txt.split("Objects inconsistants :")
    clean_output = clean_output[1].split("\n")
    clean_output = list(filter(None, clean_output))

    list_zone = []
    list_obj = []

    for i in clean_output:
        i = i.replace("ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#contains_object> ","")
        i = i.replace("<http://test.org/onto_herelles.owl#","")
        i = i.replace(">","")
        i = i.replace("<","")
        i = i.replace(")","")
        i = i.split(" ")
        for j in i:
            if "obj" in j:
                if not(j in list_obj):
                    list_obj.append(j)
            else:
                list_zone.append(j)

    return list_zone, list_obj

# %% [markdown]
# ##### Exécution du code venant du projet CEO, avec les Objects_Geo rendant l'ontologie inconsistante :

# %%
def exec_CEO(list_obj):
    list_string = []
    for i in list_obj:
        onto = get_ontology("./src/main/resources/onto_herelles.owl").load()
        # world1 = World()
        # onto1 = world1.get_ontology("./src/main/resources/onto_herelles.owl").load()
        for j in list_obj:
            if i != j:
                destroy_entity(getattr(onto, j))
        onto.save(file = "./onto_herelles.owl", format = "rdfxml")
        python_command = ["python3","./CEO2/main.py",i,'Object_Geo']
        counterfactual_output = subprocess.run(python_command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
        list_string.append(str(counterfactual_output.stdout))

    return list_string

# %% [markdown]
# ##### Récupération de la sortie du code CEO, pour traiter les explications contre-factuelle :

# %%
def clean_output_CEO(list_string):
    x = 0
    cf_final = []
    for i in list_string:
        cf_output = i #str(counterfactual_output.stdout)
        cf_output = cf_output.split("generate individuals")
        cf_output = cf_output[1]
        cf_output = cf_output.split("\\n\\n")

        cf_final.append(list_obj[x])
        for j in cf_output:
            j = j.replace("\\n","")
            j = j.replace("\"","")
            if "Assertion" in j:
                cf_final.append(j)

        x = x+1

    return cf_final

# %% [markdown]
# ##### Rangement des CF dans un tableau pour chaque objets a corriger :

# %%
def store_CF(cf_final):
    tab = []
    tab_create = []
    for i in cf_final:
        if i in list_obj:
            if len(tab_create)==0:
                tab_create.append(i)
                continue
            else:
                tab.append(tab_create)
                tab_create = []
                tab_create.append(i)
                continue
        tab_create.append(i)
    tab.append(tab_create)
    
    return tab

    # Resultat dans tab : tab[0] est un tableau contenant toutes les CF du premier obj, tab[1] ...

# %% [markdown]
# ##### mise en forme des différentes propositions de correctifs :

# %%
import re

def formatting_CF(tab):
    pattern = r"(?P<numero>\d+)Assertions: \[(?P<relations>.+?)\]Distance = (?P<distance>\d+)"

    resultat = []

    for x in range(len(tab)):
        resultat.append(tab[x][0])
        for i in range(1,len(tab[x])):
            match = re.search(pattern, tab[0][i], re.DOTALL)

            if match:
                numero = int(match.group('numero'))
                relations = match.group('relations').strip('[]').split(', ')
                distance = int(match.group('distance'))

                transformed_assertions = []
                for relation in relations:
                    relation = re.sub('[\"\'()]','',relation)
                    nom, reste = relation.split(' is a ')
                    nom_classe = reste.strip('[]')

                    res = nom, nom_classe

                    transformed_assertions.append(res)
                res = transformed_assertions, distance
                resultat.append(res)
                
            else :
                print("wow probleme")
    return resultat

# %%
val_cons, output = test_consistency()
val_incon = True
if val_cons:
    print("Ontologie cohérente.")
else :
    print("Ontologie incohérente.")
    val_incon = False
# Out:
# Result : SubClassOf(owl:Thing owl:Nothing)
#
#
#
# Explanatin number : 1
#
# 1 :ObjectPropertyAssertion(<contains_object> <zone_1> <obj_1>)
# 2 :ObjectPropertyAssertion(<Candidate_Final_State> <obj_1> <bati_industrielle>)
# 3 :ClassAssertion(<Zone_industrielle_commerciale_ou_tertiaire> <bati_industrielle>)
# 4 :EquivalentClasses(<ZoneArticle1> ObjectIntersectionOf(<Zone> ObjectComplementOf(ObjectSomeValuesFrom(<contains_object> ObjectSomeValuesFrom(<Candidate_Final_State> <Zone_industrielle_commerciale_ou_tertiaire>)))))
# 5 :ClassAssertion(<ZoneArticle1> <zone_1>)
#
#
#
# Explanatin number : 2
#
# 1 :EquivalentClasses(<ZoneEA> ObjectIntersectionOf(<Zone> ObjectAllValuesFrom(<contains_object> ObjectAllValuesFrom(<Candidate_Final_State> <Espaces_agricoles>))))
# 2 :SubClassOf(<Zone_industrielle_commerciale_ou_tertiaire> <Bati_activite>)
# 3 :SubClassOf(<Bati> <Surface_artificialisee>)
# 4 :SubClassOf(<Bati_activite> <Bati>)
# 5 :ObjectPropertyAssertion(<Candidate_Final_State> <obj_1> <bati_industrielle>)
# 6 :ObjectPropertyAssertion(<contains_object> <zone_2> <obj_1>)
# 7 :DisjointClasses(<Eau> <Espaces_agricoles> <Espaces_forestiers_et_naturels> <Surface_artificialisee>)
# 8 :ClassAssertion(<Zone_industrielle_commerciale_ou_tertiaire> <bati_industrielle>)
# 9 :ClassAssertion(<ZoneEA> <zone_2>)
#
# Objects inconsistants :
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#contains_object> <http://test.org/onto_herelles.owl#zone_1> <http://test.org/onto_herelles.owl#obj_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#contains_object> <http://test.org/onto_herelles.owl#zone_2> <http://test.org/onto_herelles.owl#obj_1>)
#
# Ontologie incohérente.

# %%
if val_incon == False:
    list_zone, list_obj = clean_output_cons(output)
    print("liste zone :",list_zone,"\nliste obj :", list_obj)
# Out:
# liste zone : ['zone_1', 'zone_2']
# liste obj : ['obj_1']

# %%
if val_incon == False:
    list_string = exec_CEO(list_obj)
    cf_final = clean_output_CEO(list_string)
    for i in cf_final:
        print(i)
    tab = store_CF(cf_final)
    resultat = formatting_CF(tab)
# Out:
# obj_1
# 1Assertions: ['(Candidate_Final_State state_geo is a [onto_herelles.State_Geo])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 5
# 2Assertions: ['(Candidate_Final_State EA_1 is a [onto_herelles.Espaces_agricoles])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 6
# 3Assertions: ['(Candidate_Final_State autre_vegetation_agricole is a [onto_herelles.Autre_vegetation_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 4Assertions: ['(Candidate_Final_State element_boise_agricole is a [onto_herelles.Element_boise_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 5Assertions: ['(Candidate_Final_State parcelle_agricole is a [onto_herelles.Parcelle_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 6Assertions: ['(Candidate_Final_State state_geo is a [onto_herelles.State_Geo])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 7Assertions: ['(Candidate_Final_State state_geo is a [onto_herelles.State_Geo])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 8Assertions: ['(Candidate_Final_State state_geo is a [onto_herelles.State_Geo])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 7
# 9Assertions: ['(Candidate_Final_State haie is a [onto_herelles.Haie])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 10Assertions: ['(Candidate_Final_State groupe_darbres_agricole_sylviculture is a [onto_herelles.Groupe_darbres_agricole_sylviculture])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 11Assertions: ['(Candidate_Final_State alignement_darbres_agricole is a [onto_herelles.Alignement_darbres_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 12Assertions: ['(Candidate_Final_State verger is a [onto_herelles.Verger])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 13Assertions: ['(Candidate_Final_State surface_herbeuse_agricole is a [onto_herelles.Surface_herbeuse_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 14Assertions: ['(Candidate_Final_State vigne is a [onto_herelles.Vigne])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 15Assertions: ['(Candidate_Final_State autres_cultures is a [onto_herelles.Autres_cultures])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 16Assertions: ['(Candidate_Final_State EA_1 is a [onto_herelles.Espaces_agricoles])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 17Assertions: ['(Candidate_Final_State EA_1 is a [onto_herelles.Espaces_agricoles])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 18Assertions: ['(Candidate_Final_State EA_1 is a [onto_herelles.Espaces_agricoles])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 8
# 19Assertions: ['(Candidate_Final_State autre_vegetation_agricole is a [onto_herelles.Autre_vegetation_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 20Assertions: ['(Candidate_Final_State element_boise_agricole is a [onto_herelles.Element_boise_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 21Assertions: ['(Candidate_Final_State parcelle_agricole is a [onto_herelles.Parcelle_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 22Assertions: ['(Candidate_Final_State autre_vegetation_agricole is a [onto_herelles.Autre_vegetation_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 23Assertions: ['(Candidate_Final_State element_boise_agricole is a [onto_herelles.Element_boise_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 24Assertions: ['(Candidate_Final_State parcelle_agricole is a [onto_herelles.Parcelle_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 25Assertions: ['(Candidate_Final_State autre_vegetation_agricole is a [onto_herelles.Autre_vegetation_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 26Assertions: ['(Candidate_Final_State element_boise_agricole is a [onto_herelles.Element_boise_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 27Assertions: ['(Candidate_Final_State parcelle_agricole is a [onto_herelles.Parcelle_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 9
# 28Assertions: ['(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_act is a [onto_herelles.Bati_activite])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 29Assertions: ['(Candidate_Final_State haie is a [onto_herelles.Haie])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 30Assertions: ['(Candidate_Final_State groupe_darbres_agricole_sylviculture is a [onto_herelles.Groupe_darbres_agricole_sylviculture])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 31Assertions: ['(Candidate_Final_State alignement_darbres_agricole is a [onto_herelles.Alignement_darbres_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 32Assertions: ['(Candidate_Final_State verger is a [onto_herelles.Verger])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 33Assertions: ['(Candidate_Final_State surface_herbeuse_agricole is a [onto_herelles.Surface_herbeuse_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 34Assertions: ['(Candidate_Final_State vigne is a [onto_herelles.Vigne])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 35Assertions: ['(Candidate_Final_State autres_cultures is a [onto_herelles.Autres_cultures])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 36Assertions: ['(Candidate_Final_State haie is a [onto_herelles.Haie])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 37Assertions: ['(Candidate_Final_State groupe_darbres_agricole_sylviculture is a [onto_herelles.Groupe_darbres_agricole_sylviculture])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 38Assertions: ['(Candidate_Final_State alignement_darbres_agricole is a [onto_herelles.Alignement_darbres_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 39Assertions: ['(Candidate_Final_State verger is a [onto_herelles.Verger])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 40Assertions: ['(Candidate_Final_State surface_herbeuse_agricole is a [onto_herelles.Surface_herbeuse_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 41Assertions: ['(Candidate_Final_State vigne is a [onto_herelles.Vigne])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 42Assertions: ['(Candidate_Final_State autres_cultures is a [onto_herelles.Autres_cultures])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 43Assertions: ['(Candidate_Final_State haie is a [onto_herelles.Haie])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 44Assertions: ['(Candidate_Final_State groupe_darbres_agricole_sylviculture is a [onto_herelles.Groupe_darbres_agricole_sylviculture])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 45Assertions: ['(Candidate_Final_State alignement_darbres_agricole is a [onto_herelles.Alignement_darbres_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 46Assertions: ['(Candidate_Final_State verger is a [onto_herelles.Verger])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 47Assertions: ['(Candidate_Final_State surface_herbeuse_agricole is a [onto_herelles.Surface_herbeuse_agricole])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 48Assertions: ['(Candidate_Final_State vigne is a [onto_herelles.Vigne])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 49Assertions: ['(Candidate_Final_State autres_cultures is a [onto_herelles.Autres_cultures])', '(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 10
# 50Assertions: ['(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state serre is a [onto_herelles.Serre])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 12
# 51Assertions: ['(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state bati_industrielle is a [onto_herelles.Zone_industrielle_commerciale_ou_tertiaire])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 12
# 52Assertions: ['(has_pixels Px_1 is a [onto_herelles.Pixel])', '(has_pixels Px_2 is a [onto_herelles.Pixel])', '(has_state b\xc3\xa2timent_rural is a [onto_herelles.B\xc3\xa2timent_rural])', '(is_in zone_1 is a [onto_herelles.ZoneArticle1])', '(is_in zone_2 is a [onto_herelles.ZoneEA])']Distance = 12

# %% [markdown]
# # SOLUTION 1:

# %% [markdown]
# aucune modif de l'onto

# %%
def porp_type_object(tab_res,relation_check):
    object_potentiel = []
    name_obj = []
    for i in range(len(tab_res)):
        if "obj_" in tab_res[i]:
            name_obj = []
            relations = []
            name_obj.append(tab_res[i])
            continue
        for j in range(len(tab_res[i][0])):
            if(relation_check in tab_res[i][0][j][0]):
                if not(tab_res[i][0][j][1] in relations):
                    relations.append(tab_res[i][0][j][1])

    name_obj.append(relations)
    object_potentiel.append(name_obj)
    name_obj = []
    
    return object_potentiel

# %%
prop_tab = porp_type_object(tab_res=resultat,relation_check = "Candidate_Final_State")

print("obj :", prop_tab[0][0])
for i in prop_tab[0][1]:
    print("porposition :", i)
# Out:
# obj : obj_1
# porposition : onto_herelles.State_Geo
# porposition : onto_herelles.Espaces_agricoles
# porposition : onto_herelles.Autre_vegetation_agricole
# porposition : onto_herelles.Element_boise_agricole
# porposition : onto_herelles.Parcelle_agricole
# porposition : onto_herelles.Haie
# porposition : onto_herelles.Groupe_darbres_agricole_sylviculture
# porposition : onto_herelles.Alignement_darbres_agricole
# porposition : onto_herelles.Verger
# porposition : onto_herelles.Surface_herbeuse_agricole
# porposition : onto_herelles.Vigne
# porposition : onto_herelles.Autres_cultures

# %% [markdown]
# # SOLUTION 2:

# %% [markdown]
# aucune modif de l'onto

# %%
onto = get_ontology("./src/main/resources/onto_herelles.owl").load()

with onto:
    obj_to_change = getattr(onto, resultat[0])

    liste_objet = []
    liste_relation = []

    for i in onto.object_properties():
        o,rel = str(i).split(".")
        attr_value = getattr(obj_to_change, rel)
        if attr_value is not None:
            try :
                for j in attr_value:
                    if not(j in liste_objet):
                        liste_objet.append(j)
                        liste_relation.append(rel)
            except Exception as e:
                if not(attr_value in liste_objet):
                    liste_objet.append(attr_value)
                    liste_relation.append(rel)
    
    for i in range(len(liste_relation)):
        print(liste_relation[i], liste_objet[i])
# Out:
# has_pixels onto_herelles.Px_1
# has_pixels onto_herelles.Px_2
# has_state onto_herelles.bati_act
# Candidate_Final_State onto_herelles.bati_industrielle
# is_in onto_herelles.zone_1
# is_in onto_herelles.zone_2

# %% [markdown]
# # SOLUTION 3 :
# ##### (supprimer intégralement l'objet pour le recréé avec les bonnes relations)

# %% [markdown]
# A faire plus tard, corriger les noms des objets. Quand on créé un objet au lieu d'ajouté toujours vigne, on souhaite mettre vigne_n.
#
#
# De plus, lorsque l'on souhaite ajouté une relation a un nouvel objet, il faut récupérer la période a laquelle l'état était ratacher. Il y aura aussi surement des modifications pour les évolutions.

# %%
onto = get_ontology("./src/main/resources/onto_herelles.owl").load()

with onto :
    obj_to_destruct = getattr(onto, resultat[0], None)
    owlready2.destroy_entity(obj_to_destruct)
    tab_relations = []
    tab_obj_name = []
    num_solution = 12 # NUMEROS DE SOLUTION QU ON CHOISIT
    
    for i in range (len(resultat[num_solution][0])):
        relation, obj_name = resultat[num_solution][0][i][0].split(" ")
        tab_relations.append(relation)
        tab_obj_name.append(obj_name)


    new_obj = Object_Geo(resultat[0])

    #Ici
    for i in range(len(tab_relations)):
        type_obj = getattr(onto,tab_obj_name[i])
        if (type_obj != None):
            try :
                getattr(new_obj,tab_relations[i]).append(type_obj)

            except Exception as e:
                setattr(new_obj,tab_relations[i],type_obj)

        else :
            new_obj2 = State_Geo(tab_obj_name[i])
            for j in onto.classes():
                if(str(j) == resultat[num_solution][0][i][1]):
                    print(j, new_obj2)
                    new_obj2.is_a.clear() # Pour enlever le fait que ca soit un state_geo (peut etre pas necessaire)
                    new_obj2.is_a.append(j)
                    break
            name_onto, name_obj = str(new_obj2).split(".")
            type_obj = getattr(onto,name_obj)
            if (type_obj != None):
                try :
                    getattr(new_obj,tab_relations[i]).append(type_obj)

                except Exception as e:
                    setattr(new_obj,tab_relations[i],type_obj)
            

    onto.save(file = "./src/main/resources/onto_herelles.owl", format = "rdfxml")
# Out:
# onto_herelles.Verger onto_herelles.verger

# %% [markdown]
# # Check inconsistance :

# %%
val_cons, output = test_consistency()
val_incon = True
if val_cons:
    print("Ontologie cohérente.")
else :
    print("Ontologie incohérente.")
    val_incon = False
# Out:
# Result : L'ONTOLOGIE EST COHERENTE !
#
#
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#has_state>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#has_pixels>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#is_in>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of_zone>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#has_rules>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#composed_by>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#createSome>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#contains_object>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#Candidate_Final_State>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#has_time>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of>)
# IrreflexiveObjectProperty(<http://test.org/onto_herelles.owl#z_has_pixels>)
# FunctionalObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of_zone>)
# FunctionalObjectProperty(<http://test.org/onto_herelles.owl#has_state>)
# FunctionalObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of>)
# FunctionalObjectProperty(<http://test.org/onto_herelles.owl#has_time>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#is_pixel_of_zone> <http://test.org/onto_herelles.owl#Pixel>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#is_in> <http://test.org/onto_herelles.owl#Object_Geo>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Elements>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#has_rules> <http://test.org/onto_herelles.owl#Image>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#contains_object> <http://test.org/onto_herelles.owl#Zone>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#has_pixels> <http://test.org/onto_herelles.owl#Object_Geo>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#composed_by> <http://test.org/onto_herelles.owl#Image>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#is_pixel_of> <http://test.org/onto_herelles.owl#Pixel>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#has_time> <http://test.org/onto_herelles.owl#State_Geo>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#is_involved> <http://test.org/onto_herelles.owl#Elements>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#z_has_pixels> <http://test.org/onto_herelles.owl#Zone>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#has_state> <http://test.org/onto_herelles.owl#Elements>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#createSome> <http://test.org/onto_herelles.owl#Object_Geo>)
# ObjectPropertyDomain(<http://test.org/onto_herelles.owl#has_duration> <http://test.org/onto_herelles.owl#Evolution_Process>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#zone_2> <http://test.org/onto_herelles.owl#EA_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_state> <http://test.org/onto_herelles.owl#Px_1> <http://test.org/onto_herelles.owl#bati_industrielle>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_pixels> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#Px_2>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_state> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#bati_act>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_time> <http://test.org/onto_herelles.owl#bati_act> <http://test.org/onto_herelles.owl#t1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#z_has_pixels> <http://test.org/onto_herelles.owl#zone_1> <http://test.org/onto_herelles.owl#Px_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_rules> <http://test.org/onto_herelles.owl#Img2> <http://test.org/onto_herelles.owl#zone_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#verger>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_time> <http://test.org/onto_herelles.owl#EA_1> <http://test.org/onto_herelles.owl#t1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_time> <http://test.org/onto_herelles.owl#bati_industrielle> <http://test.org/onto_herelles.owl#t1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_state> <http://test.org/onto_herelles.owl#Px_2> <http://test.org/onto_herelles.owl#bati_industrielle>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#is_in> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#zone_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#z_has_pixels> <http://test.org/onto_herelles.owl#zone_2> <http://test.org/onto_herelles.owl#Px_2>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#is_in> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#zone_2>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_pixels> <http://test.org/onto_herelles.owl#obj_1> <http://test.org/onto_herelles.owl#Px_1>)
# ObjectPropertyAssertion(<http://test.org/onto_herelles.owl#has_rules> <http://test.org/onto_herelles.owl#Img2> <http://test.org/onto_herelles.owl#zone_2>)
# InverseFunctionalObjectProperty(<http://test.org/onto_herelles.owl#z_has_pixels>)
# InverseFunctionalObjectProperty(<http://test.org/onto_herelles.owl#composed_by>)
# InverseFunctionalObjectProperty(<http://test.org/onto_herelles.owl#has_rules>)
# InverseFunctionalObjectProperty(<http://test.org/onto_herelles.owl#has_pixels>)
# EquivalentClasses(<http://test.org/onto_herelles.owl#Zone_Z2> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#contains_object> ObjectUnionOf(ObjectSomeValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Jardin>) ObjectSomeValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Parc>)))))
# EquivalentClasses(<http://test.org/onto_herelles.owl#ZoneEA> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#contains_object> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Espaces_agricoles>))))
# EquivalentClasses(<http://test.org/onto_herelles.owl#ZoneSA> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#contains_object> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Surface_artificialisee>))))
# EquivalentClasses(<http://test.org/onto_herelles.owl#Zone_Z2> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> ObjectUnionOf(<http://test.org/onto_herelles.owl#Jardin> <http://test.org/onto_herelles.owl#Parc>))))
# EquivalentClasses(<http://test.org/onto_herelles.owl#ZoneEau> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectAllValuesFrom(<http://test.org/onto_herelles.owl#contains_object> ObjectSomeValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Eau>))))
# EquivalentClasses(<http://test.org/onto_herelles.owl#ZoneArticle1> ObjectIntersectionOf(<http://test.org/onto_herelles.owl#Zone> ObjectComplementOf(ObjectSomeValuesFrom(<http://test.org/onto_herelles.owl#contains_object> ObjectSomeValuesFrom(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#Zone_industrielle_commerciale_ou_tertiaire>)))))
# ClassAssertion(<http://test.org/onto_herelles.owl#Pixel> <http://test.org/onto_herelles.owl#Px_1>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Object_Geo> <http://test.org/onto_herelles.owl#obj_1>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Espaces_agricoles> <http://test.org/onto_herelles.owl#EA_1>)
# ClassAssertion(<http://test.org/onto_herelles.owl#ZoneEA> <http://test.org/onto_herelles.owl#zone_2>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Image> <http://test.org/onto_herelles.owl#Img>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Zone_industrielle_commerciale_ou_tertiaire> <http://test.org/onto_herelles.owl#bati_industrielle>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Image> <http://test.org/onto_herelles.owl#Img2>)
# ClassAssertion(<http://test.org/onto_herelles.owl#ZoneArticle1> <http://test.org/onto_herelles.owl#zone_1>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Pixel> <http://test.org/onto_herelles.owl#Px_2>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Bati_activite> <http://test.org/onto_herelles.owl#bati_act>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Valid_Time> <http://test.org/onto_herelles.owl#t1>)
# ClassAssertion(<http://test.org/onto_herelles.owl#Verger> <http://test.org/onto_herelles.owl#verger>)
# InverseObjectProperties(<http://test.org/onto_herelles.owl#contains_object> <http://test.org/onto_herelles.owl#is_in>)
# InverseObjectProperties(<http://test.org/onto_herelles.owl#is_pixel_of> <http://test.org/onto_herelles.owl#has_pixels>)
# InverseObjectProperties(<http://test.org/onto_herelles.owl#is_pixel_of_zone> <http://test.org/onto_herelles.owl#z_has_pixels>)
# SubClassOf(<http://test.org/onto_herelles.owl#Carrefour> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#Ensemble_darbres_urbain> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_discontinu> <http://test.org/onto_herelles.owl#Bati_residentiel>)
# SubClassOf(<http://test.org/onto_herelles.owl#State_Geo> owl:Thing)
# SubClassOf(<http://test.org/onto_herelles.owl#Valid_Instant> <http://test.org/onto_herelles.owl#Valid_Time>)
# SubClassOf(<http://test.org/onto_herelles.owl#Etendue_deau> <http://test.org/onto_herelles.owl#Surface_en_eau_naturelle>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_discontinu_individuel> <http://test.org/onto_herelles.owl#TU_discontinu>)
# SubClassOf(<http://test.org/onto_herelles.owl#Parking> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#Cimetiere> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zones_humides> <http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels>)
# SubClassOf(<http://test.org/onto_herelles.owl#ZoneSA> <http://test.org/onto_herelles.owl#Zone>)
# SubClassOf(<http://test.org/onto_herelles.owl#ObjGeo_Evolution_Process> <http://test.org/onto_herelles.owl#Evolution_Process>)
# SubClassOf(<http://test.org/onto_herelles.owl#ZoneEA> <http://test.org/onto_herelles.owl#Zone>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_discontinu_collectif> <http://test.org/onto_herelles.owl#TU_discontinu>)
# SubClassOf(<http://test.org/onto_herelles.owl#Espace_libre_naturel> <http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels>)
# SubClassOf(<http://test.org/onto_herelles.owl#Image> owl:Thing)
# SubClassOf(<http://test.org/onto_herelles.owl#Pont> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#Foret> <http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels>)
# SubClassOf(<http://test.org/onto_herelles.owl#Bati_residentiel> <http://test.org/onto_herelles.owl#Bati>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone> <http://test.org/onto_herelles.owl#Elements>)
# SubClassOf(<http://test.org/onto_herelles.owl#Object_Geo> <http://test.org/onto_herelles.owl#Elements>)
# SubClassOf(<http://test.org/onto_herelles.owl#Pixel_Evolution_Process> <http://test.org/onto_herelles.owl#Evolution_Process>)
# SubClassOf(<http://test.org/onto_herelles.owl#Haie> <http://test.org/onto_herelles.owl#Autre_vegetation_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone_aeroportuaire> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#Ilot_de_circulation> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#Evolution_Process> owl:Thing)
# SubClassOf(<http://test.org/onto_herelles.owl#Surface_artificialisee> <http://test.org/onto_herelles.owl#State_Geo>)
# SubClassOf(<http://test.org/onto_herelles.owl#Verger> <http://test.org/onto_herelles.owl#Element_boise_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Cours_deau> <http://test.org/onto_herelles.owl#Surface_en_eau_naturelle>)
# SubClassOf(<http://test.org/onto_herelles.owl#Sable> <http://test.org/onto_herelles.owl#Espace_libre_naturel>)
# SubClassOf(<http://test.org/onto_herelles.owl#Serre> <http://test.org/onto_herelles.owl#Bati_activite>)
# SubClassOf(<http://test.org/onto_herelles.owl#Autre_Bati> <http://test.org/onto_herelles.owl#Bati>)
# SubClassOf(<http://test.org/onto_herelles.owl#Elements> owl:Thing)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone_dextraction> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#ZoneArticle1> <http://test.org/onto_herelles.owl#Zone>)
# SubClassOf(<http://test.org/onto_herelles.owl#Voies_de_communication> <http://test.org/onto_herelles.owl#Infrastructure_de_transport>)
# SubClassOf(<http://test.org/onto_herelles.owl#Surface_en_eau_artificielle> <http://test.org/onto_herelles.owl#Eau>)
# SubClassOf(<http://test.org/onto_herelles.owl#Surface_herbeuse_naturelle> <http://test.org/onto_herelles.owl#Vegetation_autre>)
# SubClassOf(<http://test.org/onto_herelles.owl#Bassin_artificiel> <http://test.org/onto_herelles.owl#Surface_en_eau_artificielle>)
# SubClassOf(<http://test.org/onto_herelles.owl#Autres_cultures> <http://test.org/onto_herelles.owl#Parcelle_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Terrain_de_Sport> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Bâtiment_rural> <http://test.org/onto_herelles.owl#Bati_activite>)
# SubClassOf(<http://test.org/onto_herelles.owl#Vegetation_autre> <http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_continu_collectif> <http://test.org/onto_herelles.owl#TU_continu>)
# SubClassOf(<http://test.org/onto_herelles.owl#Vigne> <http://test.org/onto_herelles.owl#Parcelle_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Jardin> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#Arbre_urbain> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#Parc> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#Pixel> <http://test.org/onto_herelles.owl#Elements>)
# SubClassOf(<http://test.org/onto_herelles.owl#Alignement_darbres_agricole> <http://test.org/onto_herelles.owl#Element_boise_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Espaces_agricoles> <http://test.org/onto_herelles.owl#State_Geo>)
# SubClassOf(<http://test.org/onto_herelles.owl#ZoneEau> <http://test.org/onto_herelles.owl#Zone>)
# SubClassOf(<http://test.org/onto_herelles.owl#Echangeur> <http://test.org/onto_herelles.owl#Equipement_transports>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_continu_individuel> <http://test.org/onto_herelles.owl#TU_continu>)
# SubClassOf(<http://test.org/onto_herelles.owl#Place> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Equipement_transports> <http://test.org/onto_herelles.owl#Infrastructure_de_transport>)
# SubClassOf(<http://test.org/onto_herelles.owl#Valid_Interval> <http://test.org/onto_herelles.owl#Valid_Time>)
# SubClassOf(<http://test.org/onto_herelles.owl#Autre_vegetation_agricole> <http://test.org/onto_herelles.owl#Espaces_agricoles>)
# SubClassOf(<http://test.org/onto_herelles.owl#Autre_artificialisation> <http://test.org/onto_herelles.owl#Surface_artificialisee>)
# SubClassOf(<http://test.org/onto_herelles.owl#Groupe_darbres_agricole_sylviculture> <http://test.org/onto_herelles.owl#Element_boise_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Canal> <http://test.org/onto_herelles.owl#Surface_en_eau_artificielle>)
# SubClassOf(<http://test.org/onto_herelles.owl#Route> <http://test.org/onto_herelles.owl#Voies_de_communication>)
# SubClassOf(<http://test.org/onto_herelles.owl#TU_continu> <http://test.org/onto_herelles.owl#Bati_residentiel>)
# SubClassOf(<http://test.org/onto_herelles.owl#Chemin_de_fer> <http://test.org/onto_herelles.owl#Voies_de_communication>)
# SubClassOf(<http://test.org/onto_herelles.owl#Alignement_darbres_urbain> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#Eau> <http://test.org/onto_herelles.owl#State_Geo>)
# SubClassOf(<http://test.org/onto_herelles.owl#Ecoulement_des_crues> <http://test.org/onto_herelles.owl#Obstacle>)
# SubClassOf(<http://test.org/onto_herelles.owl#Chemin> <http://test.org/onto_herelles.owl#Voies_de_communication>)
# SubClassOf(<http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels> <http://test.org/onto_herelles.owl#State_Geo>)
# SubClassOf(<http://test.org/onto_herelles.owl#Vegetation_urbaine> <http://test.org/onto_herelles.owl#Surface_artificialisee>)
# SubClassOf(<http://test.org/onto_herelles.owl#Piscine_exterieure> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Obstacle> owl:Thing)
# SubClassOf(<http://test.org/onto_herelles.owl#Route_Grande_Vitesse> <http://test.org/onto_herelles.owl#Voies_de_communication>)
# SubClassOf(<http://test.org/onto_herelles.owl#Infrastructure_de_transport> <http://test.org/onto_herelles.owl#Surface_artificialisee>)
# SubClassOf(<http://test.org/onto_herelles.owl#Parcelle_agricole> <http://test.org/onto_herelles.owl#Espaces_agricoles>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone_industrielle_commerciale_ou_tertiaire> <http://test.org/onto_herelles.owl#Bati_activite>)
# SubClassOf(<http://test.org/onto_herelles.owl#Pelouse> <http://test.org/onto_herelles.owl#Vegetation_urbaine>)
# SubClassOf(<http://test.org/onto_herelles.owl#Autre_Route> <http://test.org/onto_herelles.owl#Voies_de_communication>)
# SubClassOf(<http://test.org/onto_herelles.owl#Bati_activite> <http://test.org/onto_herelles.owl#Bati>)
# SubClassOf(<http://test.org/onto_herelles.owl#Surface_en_eau_naturelle> <http://test.org/onto_herelles.owl#Eau>)
# SubClassOf(<http://test.org/onto_herelles.owl#Element_boise_agricole> <http://test.org/onto_herelles.owl#Espaces_agricoles>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone_Z2> <http://test.org/onto_herelles.owl#Zone>)
# SubClassOf(<http://test.org/onto_herelles.owl#Remblais> <http://test.org/onto_herelles.owl#Obstacle>)
# SubClassOf(<http://test.org/onto_herelles.owl#Zone_sportif_loisir> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Terrain_vacant> <http://test.org/onto_herelles.owl#Autre_artificialisation>)
# SubClassOf(<http://test.org/onto_herelles.owl#Surface_herbeuse_agricole> <http://test.org/onto_herelles.owl#Parcelle_agricole>)
# SubClassOf(<http://test.org/onto_herelles.owl#Bati> <http://test.org/onto_herelles.owl#Surface_artificialisee>)
# SubClassOf(<http://test.org/onto_herelles.owl#Valid_Time> owl:Thing)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#composed_by> <http://test.org/onto_herelles.owl#Elements>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#Candidate_Final_State> <http://test.org/onto_herelles.owl#State_Geo>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#has_time> <http://test.org/onto_herelles.owl#Valid_Time>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#has_rules> <http://test.org/onto_herelles.owl#Zone>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#is_involved> <http://test.org/onto_herelles.owl#Evolution_Process>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#is_pixel_of_zone> <http://test.org/onto_herelles.owl#Zone>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#z_has_pixels> <http://test.org/onto_herelles.owl#Pixel>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#has_duration> <http://test.org/onto_herelles.owl#Valid_Time>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#createSome> <http://test.org/onto_herelles.owl#Obstacle>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#has_state> <http://test.org/onto_herelles.owl#State_Geo>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#contains_object> <http://test.org/onto_herelles.owl#Object_Geo>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#is_pixel_of> <http://test.org/onto_herelles.owl#Object_Geo>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#has_pixels> <http://test.org/onto_herelles.owl#Pixel>)
# ObjectPropertyRange(<http://test.org/onto_herelles.owl#is_in> <http://test.org/onto_herelles.owl#Zone>)
# Declaration(Class(<http://test.org/onto_herelles.owl#Groupe_darbres_agricole_sylviculture>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#Img2>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Surface_artificialisee>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone_sportif_loisir>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Route_Grande_Vitesse>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#Px_1>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_continu_individuel>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Ilot_de_circulation>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Chemin>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Alignement_darbres_urbain>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#contains_object>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone_industrielle_commerciale_ou_tertiaire>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Jardin>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Remblais>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Obstacle>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#is_involved>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Parc>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Vegetation_urbaine>))
# Declaration(Class(<http://test.org/onto_herelles.owl#State_Geo>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Piscine_exterieure>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Bassin_artificiel>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#t1>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Surface_herbeuse_agricole>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#is_in>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone_Z2>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Pixel_Evolution_Process>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#obj_1>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Terrain_vacant>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Espace_libre_naturel>))
# Declaration(Class(<http://test.org/onto_herelles.owl#ZoneArticle1>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Haie>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Eau>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Object_Geo>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Chemin_de_fer>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Route>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Surface_herbeuse_naturelle>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Image>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Terrain_de_Sport>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Valid_Time>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Pelouse>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Bati>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zones_humides>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone_aeroportuaire>))
# Declaration(Class(<http://test.org/onto_herelles.owl#ZoneSA>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#bati_industrielle>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Surface_en_eau_naturelle>))
# Declaration(Class(<http://test.org/onto_herelles.owl#ZoneEau>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Ecoulement_des_crues>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Evolution_Process>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#zone_1>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#Candidate_Final_State>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#has_duration>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Autre_artificialisation>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Echangeur>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_discontinu>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Arbre_urbain>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_continu>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#verger>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Serre>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#composed_by>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Autre_Bati>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Place>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Bâtiment_rural>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Cours_deau>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Valid_Instant>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#EA_1>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Autre_Route>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Vegetation_autre>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#has_time>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Autres_cultures>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Autre_vegetation_agricole>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Infrastructure_de_transport>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#zone_2>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Voies_de_communication>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_discontinu_collectif>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#has_rules>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Elements>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Etendue_deau>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Parcelle_agricole>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Bati_activite>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_continu_collectif>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Sable>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#Px_2>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Cimetiere>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Ensemble_darbres_urbain>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#has_pixels>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Zone_dextraction>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#Img>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Bati_residentiel>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Equipement_transports>))
# Declaration(NamedIndividual(<http://test.org/onto_herelles.owl#bati_act>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Carrefour>))
# Declaration(Class(<http://test.org/onto_herelles.owl#ObjGeo_Evolution_Process>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#createSome>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#z_has_pixels>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#is_pixel_of_zone>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Pont>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels>))
# Declaration(ObjectProperty(<http://test.org/onto_herelles.owl#has_state>))
# Declaration(Class(<http://test.org/onto_herelles.owl#TU_discontinu_individuel>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Foret>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Verger>))
# Declaration(Class(<http://test.org/onto_herelles.owl#ZoneEA>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Pixel>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Vigne>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Element_boise_agricole>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Canal>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Parking>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Alignement_darbres_agricole>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Espaces_agricoles>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Valid_Interval>))
# Declaration(Class(<http://test.org/onto_herelles.owl#Surface_en_eau_artificielle>))
# DisjointClasses(<http://test.org/onto_herelles.owl#Elements> <http://test.org/onto_herelles.owl#Evolution_Process> <http://test.org/onto_herelles.owl#Image> <http://test.org/onto_herelles.owl#State_Geo> <http://test.org/onto_herelles.owl#Valid_Time>)
# DisjointClasses(<http://test.org/onto_herelles.owl#Object_Geo> <http://test.org/onto_herelles.owl#Pixel> <http://test.org/onto_herelles.owl#Zone>)
# DisjointClasses(<http://test.org/onto_herelles.owl#Eau> <http://test.org/onto_herelles.owl#Espaces_agricoles> <http://test.org/onto_herelles.owl#Espaces_forestiers_et_naturels> <http://test.org/onto_herelles.owl#Surface_artificialisee>)
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#EA_1>
# L'individu <http://test.org/onto_herelles.owl#EA_1> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#State_Geo>, <http://test.org/onto_herelles.owl#Espaces_agricoles>]
# L'individu <http://test.org/onto_herelles.owl#EA_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#t1> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#Img>
# L'individu <http://test.org/onto_herelles.owl#Img> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Image>]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#Img2>
# L'individu <http://test.org/onto_herelles.owl#Img2> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Image>]
# L'individu <http://test.org/onto_herelles.owl#Img2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#zone_1> ), Node( <http://test.org/onto_herelles.owl#zone_2> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#Px_1>
# L'individu <http://test.org/onto_herelles.owl#Px_1> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Elements>, <http://test.org/onto_herelles.owl#Pixel>]
# L'individu <http://test.org/onto_herelles.owl#Px_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#bati_industrielle> )]
# L'individu <http://test.org/onto_herelles.owl#Px_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#obj_1> )]
# L'individu <http://test.org/onto_herelles.owl#Px_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#zone_1> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#Px_2>
# L'individu <http://test.org/onto_herelles.owl#Px_2> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Elements>, <http://test.org/onto_herelles.owl#Pixel>]
# L'individu <http://test.org/onto_herelles.owl#Px_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#bati_industrielle> )]
# L'individu <http://test.org/onto_herelles.owl#Px_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#obj_1> )]
# L'individu <http://test.org/onto_herelles.owl#Px_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#zone_2> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#bati_act>
# L'individu <http://test.org/onto_herelles.owl#bati_act> a les types suivants : [<http://test.org/onto_herelles.owl#Bati>, owl:Thing, <http://test.org/onto_herelles.owl#Bati_activite>, <http://test.org/onto_herelles.owl#Surface_artificialisee>, <http://test.org/onto_herelles.owl#State_Geo>]
# L'individu <http://test.org/onto_herelles.owl#bati_act> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#t1> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#bati_industrielle>
# L'individu <http://test.org/onto_herelles.owl#bati_industrielle> a les types suivants : [<http://test.org/onto_herelles.owl#Bati>, owl:Thing, <http://test.org/onto_herelles.owl#Zone_industrielle_commerciale_ou_tertiaire>, <http://test.org/onto_herelles.owl#Bati_activite>, <http://test.org/onto_herelles.owl#Surface_artificialisee>, <http://test.org/onto_herelles.owl#State_Geo>]
# L'individu <http://test.org/onto_herelles.owl#bati_industrielle> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#t1> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#obj_1>
# L'individu <http://test.org/onto_herelles.owl#obj_1> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Elements>, <http://test.org/onto_herelles.owl#Object_Geo>]
# L'individu <http://test.org/onto_herelles.owl#obj_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#verger> )]
# L'individu <http://test.org/onto_herelles.owl#obj_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#Px_2> ), Node( <http://test.org/onto_herelles.owl#Px_1> )]
# L'individu <http://test.org/onto_herelles.owl#obj_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#bati_act> )]
# L'individu <http://test.org/onto_herelles.owl#obj_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#zone_1> ), Node( <http://test.org/onto_herelles.owl#zone_2> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#t1>
# L'individu <http://test.org/onto_herelles.owl#t1> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Valid_Time>]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#verger>
# L'individu <http://test.org/onto_herelles.owl#verger> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Element_boise_agricole>, <http://test.org/onto_herelles.owl#State_Geo>, <http://test.org/onto_herelles.owl#Espaces_agricoles>, <http://test.org/onto_herelles.owl#Verger>]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#zone_1>
# L'individu <http://test.org/onto_herelles.owl#zone_1> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#Elements>, <http://test.org/onto_herelles.owl#ZoneArticle1>, <http://test.org/onto_herelles.owl#Zone>]
# L'individu <http://test.org/onto_herelles.owl#zone_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#obj_1> )]
# L'individu <http://test.org/onto_herelles.owl#zone_1> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#Px_1> )]
#
#
#
# INDIVIDU : <http://test.org/onto_herelles.owl#zone_2>
# L'individu <http://test.org/onto_herelles.owl#zone_2> a les types suivants : [owl:Thing, <http://test.org/onto_herelles.owl#ZoneEA>, <http://test.org/onto_herelles.owl#Elements>, <http://test.org/onto_herelles.owl#ZoneArticle1>, <http://test.org/onto_herelles.owl#Zone>]
# L'individu <http://test.org/onto_herelles.owl#zone_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#EA_1> )]
# L'individu <http://test.org/onto_herelles.owl#zone_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#obj_1> )]
# L'individu <http://test.org/onto_herelles.owl#zone_2> a les props : Nodeset[Node( <http://test.org/onto_herelles.owl#Px_2> )]
#
# Ontologie cohérente.

# %%
if val_incon == False:
    list_zone, list_obj = clean_output_cons(output)
    print("liste zone :",list_zone,"\nliste obj :", list_obj)

# %%
if val_incon == False:
    list_string = exec_CEO(list_obj)
    cf_final = clean_output_CEO(list_string)
    for i in cf_final:
        print(i)
    tab = store_CF(cf_final)
    resultat = formatting_CF(tab)

# %% [markdown]
# # Futures étapes à faire :
#
# - Module évolution et temporel à tester correctement avec un exemple simple.
# - Amélioration de la solution 3 : voir la section pour plus de détails.
# - Implémentation de nouvelles règles simples.
# - ? Améliorer les propositions de correctifs ?

# %% [markdown]
# ### Autres étapes vraiment plus tard:
# - code dans un fichier python
# - faire des fonctions pour une meilleur lecture du code
# - commenter mon code

# %%
# from owlready2 import *
# import owlready2
# owlready2.JAVA_EXE = "/usr/bin/java"

# onto = get_ontology("onto_herelles.owl").load()

# with onto :    
#     try:
#         sync_reasoner_pellet(infer_property_values=True, infer_data_property_values=True, debug=2, keep_tmp_file= False)
#         print("SIIII", owlready2.JAVA_EXE)catch
#         print("L'ontologie est consistante.")

#     except OwlReadyInconsistentOntologyError as e1:
#         print("L'ontologie est inconsistante car :\n" + str(e1))
